# %% [markdown]
# # Main Heading
# ## Sub Heading
# ### small heading
#
# ---
# This is regualer txt
#
# - This list 1
# - This list 2

# %%
print("Hello")
# Out:
# Helloo

# %% [markdown]
# #This is another marks down sell
#
# ---
#
# -List
#
# -List

# %% [markdown]
# ## IN google import drive file
#
# ---
# from google.colab import drive
#
# drive.mount('/content/drive')
#
# ---
# import pandas as pd
#
# df = pd.read_csv('/content/drive/MyDrive/data.csv')
#
# ---
# ###Output
# df
#
#    name  age
# 0  Yash   20
# 1  Rahul  21
# 2  Amit   22

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\asus\OneDrive\Desktop\AI_Automation_dep\AI_Automation_dep\18-Aug-Jupiter\venv\scripts\python.exe

# %%
import pandas as pd

data = {
    "Name": ["Yash", "Rahul", "Amit"],
    "Age": [20, 21, 22]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0   Yash   20
# 1  Rahul   21
# 2   Amit   22

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y)
plt.title("Sample Graph")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
