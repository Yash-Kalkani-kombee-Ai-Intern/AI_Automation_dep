# %% [markdown]
# # A/B Testing Comparison Report
#
# ## 1. Title
#
# **Comparison of Prompt A and Prompt B for LLM Performance**
#
# ## 2. Objective
#
# The objective of this experiment is to compare two different prompt variations for the same LLM task and determine which prompt provides better results based on quantitative evaluation.
#
# ## 3. Task Description
#
# **Task:** [Example: Answer general knowledge questions in simple language]
#
# The same task and same input dataset were used for both Prompt A and Prompt B to ensure a fair comparison.
#
# ## 4. Prompt A – Control Prompt
#
# **Prompt A:**
#
#  What is Python?
#
#     Python is a high-level, easy-to-learn programming language used for web development, data analysis, automation, AI, and many other applications.
#
# What is Machine Learning?
#
#     Machine Learning is a technology that enables computers to learn patterns from data and make predictions or decisions without being explicitly programmed for every task.
#
#
# What is SQL?
#
#     SQL is a language used to store, retrieve, update, and manage data in databases.
#
#
# what is API?
#
#     API (Application Programming Interface) is a way for different software applications to communicate and exchange data with each other.
#
#
# What is Git?
#
#     Git is a version-control system that tracks changes in code and helps developers collaborate on projects.
#
#
# ## 5. Prompt B – Experimental Prompt
#
# **Prompt B:**
#
# You are a Python teacher. Explain Python to a complete beginner using simple language. Mention 3 common uses and give 1 small example. Keep the answer within 5 lines.
#
#     Python is a simple programming language used to give instructions to computers; common uses: Web Development, Data Science, and Automation; example: `print("Hello, World!")` displays a message.
#
# you are Machine Learning expert. Explain to a complete beginner . explain overview of it in single or two line and also give one example for it.
#
#     Machine Learning is a part of AI where computers learn from data to make predictions or decisions without being explicitly programmed for every task; example: **Gmail learns to identify and filter spam emails automatically.**
#
# you are a sql teacher . explain to a complete new student who don't know about what is sql. explain in esay way and also give one real life example and make it sort. give me two line of explantion .
#
#     SQL is a language used to store, find, and manage data in databases easily.Real-life example: A college uses SQL to find a student’s name, marks, or attendance from its database.
#
# Act like a you are expert in API and you need to teach or explain to complete new beginner what is api and in esay way and real life example and what is use for and explain in sort and in two line .
#
#     API is a way for two different software applications to communicate and share data with each other.Real-life example: A weather app uses a Weather API to get live weather data; APIs are used to connect apps and services.
#
# You are expert in git hub so explain to who don't know about github who is non it field , explain in esay way and why we need this and explain in sort but cover complete beginner detail in 3 line .
#
#     GitHub is an online platform where you can store and manage your code and project files safely.We need it to keep track of changes, work with others, and avoid losing previous versions of a project.Real-life example: Like Google Drive for projects, but with tools to track every change made to the files.
