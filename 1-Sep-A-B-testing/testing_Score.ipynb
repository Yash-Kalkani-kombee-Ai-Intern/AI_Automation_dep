# %% [markdown]
# # A/B Testing Comparison Report
#
# ## 1. Title
#
# **Comparison of Prompt A and Prompt B for LLM Performance**
#
# ## 2. Objective
#
# The objective of this experiment is to compare Prompt A and Prompt B and determine which prompt produces better answers based on **accuracy, clarity, relevance, completeness, and instruction-following**.
#
# ## 3. Task Description
#
# **Task:** Explain basic IT concepts to beginners using simple and short language.
#
# The same 5 questions were tested using both Prompt A and Prompt B.
#
# ---
#
# ## 4. Prompt A – Control Prompt
#
# **Prompt A:**
#
# * What is Python?
# * What is Machine Learning?
# * What is SQL?
# * What is API?
# * What is Git?
#
# ### Prompt A Outputs
#
# | Question         | Output Quality |
# | ---------------- | -------------: |
# | Python           |           9/10 |
# | Machine Learning |           9/10 |
# | SQL              |           9/10 |
# | API              |           9/10 |
# | Git              |           9/10 |
#
# **Average Quality Score: 9.0/10**
#
# Prompt A produced correct and concise answers, but it did not provide specific instructions about audience, explanation style, examples, or length.
#
# ---
#
# ## 5. Prompt B – Experimental Prompt
#
# Prompt B provided additional instructions such as:
#
# * Beginner-friendly explanation
# * Simple language
# * Real-life examples
# * Specific answer length
# * Common uses
# * Role-based instructions such as teacher/expert
#
# ### Prompt B Outputs
#
# | Question         | Output Quality | Instruction Following |
# | ---------------- | -------------: | --------------------: |
# | Python           |         9.5/10 |                 10/10 |
# | Machine Learning |         9.5/10 |                 10/10 |
# | SQL              |         9.5/10 |                 10/10 |
# | API              |         9.5/10 |                 10/10 |
# | GitHub           |         9.5/10 |                 10/10 |
#
# **Average Quality Score: 9.5/10**
#
# Prompt B produced more structured, beginner-friendly answers and followed the requested constraints more explicitly.
#
# ---
#
# ## 6. Test Dataset
#
# **Total Test Inputs: 5**
#
# 1. What is Python?
# 2. What is Machine Learning?
# 3. What is SQL?
# 4. What is API?
# 5. What is Git?
#
# The questions were intended to test basic technical concept explanations for beginners.
#
# ---
#
# ## 7. Evaluation Metrics
#
# | Metric                  | Description                                                   | Weight |
# | ----------------------- | ------------------------------------------------------------- | -----: |
# | Accuracy                | Whether the information is technically correct                |    40% |
# | Quality & Clarity       | Easy to understand and useful for beginners                   |    30% |
# | Instruction Following   | Follows requested length, examples, style, etc.               |    20% |
# | Relevance & Conciseness | Directly answers the question without unnecessary information |    10% |
#
# ---
#
# ## 8. Detailed Scoring
#
# ### Prompt A
#
# | Metric                  |            Score |
# | ----------------------- | ---------------: |
# | Accuracy                |            10/10 |
# | Quality & Clarity       |             9/10 |
# | Instruction Following   |             8/10 |
# | Relevance & Conciseness |             9/10 |
# | **Overall Score**       | **9.1/10 (91%)** |
#
# ### Prompt B
#
# | Metric                  |            Score |
# | ----------------------- | ---------------: |
# | Accuracy                |            10/10 |
# | Quality & Clarity       |           9.5/10 |
# | Instruction Following   |            10/10 |
# | Relevance & Conciseness |           9.5/10 |
# | **Overall Score**       | **9.7/10 (97%)** |
#
# ---
#
# ## 9. Results
#
# | Metric                  | Prompt A | Prompt B | Better       |
# | ----------------------- | -------: | -------: | ------------ |
# | Accuracy                |     100% |     100% | Tie          |
# | Quality & Clarity       |      90% |      95% | Prompt B     |
# | Instruction Following   |      80% |     100% | Prompt B     |
# | Relevance & Conciseness |      90% |      95% | Prompt B     |
# | **Overall Score**       |  **91%** |  **97%** | **Prompt B** |
#
# ### Score Improvement
#
# Prompt B improved the overall score from **91% to 97%**, giving an improvement of approximately **6.6% relative to Prompt A**.
#
# ---
#
# ## 10. Statistical Analysis
#
# A statistical significance test cannot be reliably calculated from only 5 manually evaluated questions. A larger dataset, such as **50–100 test inputs**, would be required for a meaningful statistical comparison.
#
# **Current result:** Prompt B performed better in the manual evaluation, but statistical significance is **not established**.
#
# ---
#
# ## 11. Winner
#
# ### 🏆 Winning Prompt: Prompt B
#
# Prompt B achieved a higher overall score of **97%**, compared with **91%** for Prompt A.
#
# ---
#
# ## 12. Recommendation
#
# **Prompt B is recommended** because it gives more detailed instructions about the target audience, explanation style, examples, and answer length. This results in more consistent and beginner-friendly responses.
#
# ---
#
# ## 13. Conclusion
#
# The A/B test shows that **Prompt B performed better than Prompt A** for beginner-level technical explanations. Prompt A already produced accurate answers, but Prompt B provided better instruction-following, clarity, and consistency. Therefore, **Prompt B is the preferred prompt for this task**.
