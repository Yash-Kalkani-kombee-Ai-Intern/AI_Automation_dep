# %%
students = ["Yash", "Rahul", "Amit", "Jay"]

print(students)
print(type(students))
# Out:
# ['Yash', 'Rahul', 'Amit', 'Jay']
# <class 'list'>

# %%
students = ["Yash", "Rahul", "Amit", "Jay"]

print(students[0])
print(students[1])
print(students[-1])
# Out:
# Yash
# Rahul
# Jay

# %%
students.append("Raj")

print(students)
# Out:
# ['Yash', 'Rahul', 'Amit', 'Jay', 'Raj']

# %%
students[1] = "Ravi"

print(students)
# Out:
# ['Yash', 'Ravi', 'Amit', 'Jay', 'Raj']

# %%
students.remove("Amit")

print(students)
# Out:
# ['Yash', 'Ravi', 'Jay', 'Raj']

# %%
print(len(students))
# Out:
# 4

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[0])
print(numbers[-1])
print(len(numbers))
print(numbers.append(60))
numbers[1]=25
print(numbers)
numbers.remove(40)
print(numbers)
# Out:
# 10
# 50
# 5
# None
# [10, 25, 30, 40, 50, 60]
# [10, 25, 30, 50, 60]

# %%
numbers = (10, 20, 30, 40, 50)

print(numbers)
print(type(numbers))
print(numbers[0])
print(numbers[-1])
print(len(numbers))
# Out:
# (10, 20, 30, 40, 50)
# <class 'tuple'>
# 10
# 50
# 5

# %%
numbers = [10, 20, 30]
print(type(numbers))

numbers = (10, 20, 30)
print(type(numbers))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers[0] = 100
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 numbers[0] = 100
#       2 print(numbers)
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits = {"Apple", "Banana", "Mango", "Apple"}

print(fruits)
print(type(fruits))
# Out:
# {'Apple', 'Banana', 'Mango'}
# <class 'set'>

# %%
fruits.add("Orange")
print(fruits)

fruits.remove("Banana")
print(fruits)
# Out:
# {'Apple', 'Banana', 'Orange', 'Mango'}
# {'Apple', 'Orange', 'Mango'}

# %%
print("Mango" in fruits)
print("Grapes" in fruits)
# Out:
# True
# False

# %%
print(len(fruits))
# Out:
# 3

# %%
student = {
    "name": "Yash",
    "age": 20,
    "course": "B.Sc IT"
}

print(student)
print(type(student))
# Out:
# {'name': 'Yash', 'age': 20, 'course': 'B.Sc IT'}
# <class 'dict'>

# %%
print(student["name"])
print(student["age"])
print(student["course"])
# Out:
# Yash
# 20
# B.Sc IT

# %%
student["age"] = 21

print(student)
# Out:
# {'name': 'Yash', 'age': 21, 'course': 'B.Sc IT'}

# %%
student["city"] = "Surat"

print(student)
# Out:
# {'name': 'Yash', 'age': 21, 'course': 'B.Sc IT', 'city': 'Surat'}

# %%
print(student.keys())
print(student.values())
print(student.items())
# Out:
# dict_keys(['name', 'age', 'course', 'city'])
# dict_values(['Yash', 21, 'B.Sc IT', 'Surat'])
# dict_items([('name', 'Yash'), ('age', 21), ('course', 'B.Sc IT'), ('city', 'Surat')])

# %%
student.pop("city")
print(student)
# Out:
# {'name': 'Yash', 'age': 21, 'course': 'B.Sc IT'}

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers[0])
print(numbers[1])
print(numbers[2])
# Out:
# 10
# 20
# 30

# %%
print(numbers[-1])
print(numbers[-2])
# Out:
# 50
# 40

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers[1:4])
# Out:
# [20, 30, 40]

# %%
print(numbers[:3])    # First 3
print(numbers[2:])    # Index 2 thi end sudhi
print(numbers[:])     # Complete list
# Out:
# [10, 20, 30]
# [30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
print(numbers[::2])
# Out:
# [10, 30, 50]

# %%
print(numbers[::3])
# Out:
# [10, 40]

# %%
numbers = [10, 20, 30, 40, 50]

for number in numbers:
    print(number)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
numbers = [10, 15, 20, 25, 30]

for number in numbers:
    if number > 20:
        print(number)
# Out:
# 25
# 30

# %%
student = {
    "name": "Yash",
    "age": 20,
    "course": "B.Sc IT"
}

for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Yash
# age : 20
# course : B.Sc IT

# %%
colors = {"Red", "Blue", "Green"}

for color in colors:
    print(color)
# Out:
# Blue
# Red
# Green

# %%
numbers = [10,20,30,40,50]

for i in numbers:
    print(i*i)
# Out:
# 100
# 400
# 900
# 1600
# 2500

# %%
numbers = [10,20,30,40,50]

for i in numbers:
    if i > 30:
        print(i)
# Out:
# 40
# 50

# %%
numbers = [10,20,30,40,50]
x = 0

for i in numbers:
    x = x + i


print(f"This is you total answer = {x}")
# Out:
# This is you total answer = 150
