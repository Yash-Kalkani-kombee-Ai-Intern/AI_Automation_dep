# %%
import os
from dotenv import load_dotenv
from google import genai

load_dotenv()

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

print("Gemini client created successfully!")
# Out:
# Gemini client created successfully!

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Write a short paragraph about Artificial Intelligence."
)

print(response.text)
# Out:
# Artificial Intelligence (AI) refers to the simulation of human intelligence in machines programmed to think, learn, and solve problems. By analyzing vast amounts of data through complex algorithms, AI systems can recognize patterns, understand natural language, and make decisions with increasing autonomy. From everyday applications like virtual assistants and recommendation engines to groundbreaking advances in healthcare and autonomous driving, AI is rapidly reshaping how we live and work. As this technology continues to evolve, it stands as one of the most transformative forces of the modern era, holding immense potential to enhance human capability while driving the future of global innovation.

# %%
topic = "Artificial Intelligence in Education"

prompt = f"""
Write a short blog paragraph about: {topic}

Tone: Professional
Length: Short
"""

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents=prompt
)

print(response.text)
# Out:
# Artificial intelligence is fundamentally reshaping the educational landscape, driving a transition toward highly personalized and data-driven learning environments. By leveraging adaptive algorithms, AI-powered platforms can identify individual learning gaps in real time, allowing educators to tailor instruction to each student's unique pace while streamlining time-consuming administrative tasks. Far from replacing the vital human element in teaching, this technological evolution empowers educators to focus on mentorship, critical thinking, and student engagement—ultimately preparing the next generation for an increasingly complex digital future.

# %%
from llm import generate_text

result = generate_text(
    "Artificial Intelligence in Education",
    "blog",
    "professional",
    "short"
)

print(result)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# # Transforming the Classroom: The Role of Artificial Intelligence in Education
#
# Artificial Intelligence (AI) is no longer a futuristic concept—it is actively reshaping how educators teach and how students learn. From administrative efficiency to personalized instruction, AI is driving a significant transformation in the global educational landscape.
#
# When implemented strategically, AI does not replace the human element in teaching; rather, it empowers educators and optimizes the learning experience for students.
#
# Here is a look at how AI is influencing modern education and what it means for the future of learning.
#
# ---
#
# ## Key Applications of AI in Education
#
# ### 1. Personalized Learning Paths
# Every student learns at a different pace and through different modalities. AI-powered adaptive learning platforms analyze individual student performance in real time, identifying knowledge gaps and adjusting the difficulty of content accordingly. This ensures that advanced learners remain challenged while struggling students receive the targeted intervention they need.
#
# ### 2. Administrative Efficiency for Educators
# Teachers spend a significant portion of their time on administrative tasks, such as grading assignments, managing schedules, and tracking attendance. AI tools can automate routine grading for objective assessments and assist in feedback generation. By reducing workload stress, AI allows educators to focus more on direct instruction, curriculum development, and student mentorship.
#
# ### 3. Accessible and Scalable Support
# AI-driven tutoring systems and intelligent chatbots provide 24/7 assistance to students outside the classroom. These tools can answer frequently asked questions, guide students through complex problem-solving steps, and offer language translation services, making quality support accessible to a broader demographic.
#
# ---
#
# ## Navigating the Challenges
#
# While the benefits are substantial, integrating AI into education requires careful navigation of several key challenges:
#
# * **Data Privacy and Security:** Protecting sensitive student data is paramount. Educational institutions must ensure AI vendors adhere to strict compliance standards.
# * **Academic Integrity:** The rise of generative AI tools necessitates clear policies regarding acceptable use, plagiarism, and critical thinking development.
# * **Equitable Access:** Ensuring all students, regardless of socioeconomic status, have access to AI-driven educational resources is critical to preventing an expanding digital divide.
#
# ---
#
# ## The Path Forward
#
# The goal of AI in education is not automation for its own sake, but the enhancement of human potential. As these tools continue to evolve, educational leaders must focus on creating balanced, ethical frameworks that leverage technology while preserving the irreplaceable value of human mentorship and collaborative learning.
#
# By embracing AI thoughtfully, educators can cultivate a more dynamic, inclusive, and effective learning environment for the workforce of tomorrow.
